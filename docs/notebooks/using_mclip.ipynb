# %% [markdown]
# # Multilingual Text To Image search with MultilingualCLIP

# %% [markdown]
# Most text-image models are only able to provide embeddings for text in a single language, typically English. Multilingual CLIP models, however, are models that have been trained on multiple different languages. This allows the model the produce similar embeddings for the same sentence in multiple different languages.
#
# This guide will show you how to finetune a multilingual CLIP model for a text to image retrieval in non-English languages.
#
# *Note, please consider switching to GPU/TPU Runtime for faster inference.*

# %% [markdown]
# ## Install

# %%
# !pip install 'finetuner[full]'

# %% [markdown]
# ## Task

# %% [markdown]
# We'll be finetuning multilingual CLIP on the [german x-market dataset](https://xmrec.github.io/data/de/), specifically the electronics section.
#
# Each product in the dataset contains several attributes, we will be making use of the image and category attributes to create a [`Document`](https://docarray.jina.ai/fundamentals/document/#document) containing two [chunks](https://docarray.jina.ai/fundamentals/document/nested/#nested-structure), one containing the image and another containing the category of the product.

# %% [markdown]
# ## Data
# I am not sure what data to show to users as an example, this will be left blank for now

# %%
import finetuner
from docarray import DocumentArray, Document
import os
os.environ['JINA_FINETUNER_REGISTRY'] = 'https://api-staging.finetuner.fit'
finetuner.login(force=True)
# Out:
# VBox(children=(VBox(children=(HTML(value="\n<div class='custom-container'>\n    <style>\n        .button1 {\n …

# %%
LANG = "de"
train_data = DocumentArray.load(f"train-{LANG}.da")
eval_data = DocumentArray.load(f"eval-{LANG}.da")
train_data.summary()
# Out:
# ╭────────────────── Documents Summary ───────────────────╮
# │                                                        │
# │   Type                      DocumentArrayInMemory      │
# │   Length                    233                        │
# │   Homogenous Documents      True                       │
# │   Has nested Documents in   ('chunks',)                │
# │   Common Attributes         ('id', 'tags', 'chunks')   │
# │   Multimodal dataclass      True                       │
# │                                                        │
# ╰────────────────────────────────────────────────────────╯
# ╭──────────────────────── Attributes Summary ────────────────────────╮
# │                                                                    │
# │   Attribute   Data type         #Unique values   Has empty value   │
# │  ────────────────────────────────────────────────────────────────  │
# │   chunks      ('ChunkArray',)   233              False             │
# │   id          ('str',)          233              False             │
# │   tags        ('dict',)         233              False             │
# │                                                                    │
# ╰────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Backbone Model
# Currently, we only support one multilingual CLIP model, which has been made available by [open-clip](https://github.com/mlfoundations/open_clip).

# %% [markdown]
# ## Fine-tuning
# Now that our data has been prepared, we can start our fine-tuning run.

# %%
import finetuner

run = finetuner.fit(
    model='xlm-roberta-base-ViT-B-32::laion5b_s13b_b90k',
    train_data=train_data,
    eval_data=eval_data,
    epochs=5,
    learning_rate=1e-6,
    loss='CLIPLoss',
    device='cpu',
)
# Out:
# Pushing a DocumentArray to Hubble under the name finetuner-dastorage-finetuner-stupefied-einstein-train ...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Pushing a DocumentArray to Hubble under the name finetuner-dastorage-finetuner-stupefied-einstein-eval ...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# You may notice that this piece of code looks very similar to the one used to fine-tune regular clip models, as shown [here](https://finetuner.jina.ai/notebooks/text_to_image/). The only real difference is the data being provided and the model being used.

# %% [markdown]
# ## Monitoring
#
# Now that we've created a run, let's see its status. You can monitor the run by checking the status - `run.status()` and - the logs - `run.logs()` or - `run.stream_logs()`.

# %%
# note, the fine-tuning might takes 20~ minutes
for entry in run.stream_logs():
    print(entry)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [10:10:06] INFO     Starting finetuner run ...                                                           __main__.py:113
#            DEBUG    Found Jina AI Cloud authentication token                                             __main__.py:125
#            DEBUG    Running in online mode                                                               __main__.py:126
#            INFO     Reading config ...                                                                   __main__.py:133
#            DEBUG    Reading config from stream                                                           __main__.py:145
#            INFO     Parsing config ...                                                                   __main__.py:148
#            INFO     Config loaded 📜                                                                     __main__.py:150
#            INFO     Run name: stupefied-einstein                                                         __main__.py:152
#            INFO     Experiment name: finetuner                                                           __main__.py:153
#            DEBUG    Device set to [cpu]                                                                  __main__.py:156
#            DEBUG    Artifact ID set to 63775941344182ab9a8f7a58                                          __main__.py:164
#            INFO     Bulding the tuner components ...                                                     __main__.py:166
#            INFO     Building models ...                                                                    parser.py:193
#            DEBUG    Model name: xlm-roberta-base-ViT-B-32::laion5b_s13b_b90k                               parser.py:195
#            DEBUG    Model options: {}                                                                      parser.py:196
#            INFO     Loaded xlm-roberta-base-ViT-B-32 model config.                                        factory.py:127
#
# Downloading:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 615/615 [00:00<00:00, 991kB/s]
#
# Downloading:   0%|          | 0.00/1.04G [00:00<?, ?B/s]
# Downloading:   1%|          | 9.67M/1.04G [00:00<00:10, 101MB/s]
# Downloading:   2%|▏         | 19.7M/1.04G [00:00<00:10, 104MB/s]
# Downloading:   3%|▎         | 29.9M/1.04G [00:00<00:10, 105MB/s]
# Downloading:   4%|▍         | 40.0M/1.04G [00:00<00:10, 106MB/s]
# Downloading:   5%|▍         | 50.2M/1.04G [00:00<00:10, 106MB/s]
# Downloading:   6%|▌         | 60.4M/1.04G [00:00<00:09, 106MB/s]
# Downloading:   7%|▋         | 70.6M/1.04G [00:00<00:09, 106MB/s]
# Downloading:   8%|▊         | 80.8M/1.04G [00:00<00:09, 107MB/s]
# Downloading:   9%|▊         | 91.1M/1.04G [00:00<00:09, 107MB/s]
# Downloading:  10%|▉         | 101M/1.04G [00:01<00:09, 107MB/s]
# Downloading:  10%|█         | 112M/1.04G [00:01<00:09, 107MB/s]
# Downloading:  11%|█▏        | 122M/1.04G [00:01<00:13, 70.8MB/s]
# Downloading:  12%|█▏        | 130M/1.04G [00:01<00:14, 65.3MB/s]
# Downloading:  13%|█▎        | 140M/1.04G [00:01<00:13, 74.1MB/s]
# Downloading:  14%|█▍        | 150M/1.04G [00:01<00:11, 81.9MB/s]
# Downloading:  15%|█▌        | 161M/1.04G [00:01<00:10, 88.2MB/s]
# Downloading:  16%|█▌        | 171M/1.04G [00:01<00:10, 93.0MB/s]
# Downloading:  17%|█▋        | 181M/1.04G [00:02<00:09, 96.5MB/s]
# Downloading:  18%|█▊        | 191M/1.04G [00:02<00:09, 99.1MB/s]
# Downloading:  19%|█▉        | 201M/1.04G [00:02<00:09, 100MB/s]
# Downloading:  20%|█▉        | 211M/1.04G [00:02<00:08, 102MB/s]
# ping
# 2022-11-18 10:40:37.771584
# ping
# 2022-11-18 10:40:52.773114
# ping
# 2022-11-18 10:41:07.777723
# ping
# 2022-11-18 10:41:22.780806
# ping
# 2022-11-18 10:41:37.783316
# ping
# 2022-11-18 10:41:52.789598
# ping
# 2022-11-18 10:42:07.794797
# ping
# 2022-11-18 10:42:22.797819
# ping
# 2022-11-18 10:42:37.800494
# ping
# 2022-11-18 10:42:52.814217
# ping
# 2022-11-18 10:43:07.816830
# ping
# 2022-11-18 10:43:22.819871
# ping
# 2022-11-18 10:43:37.823682
# ping
# 2022-11-18 10:43:52.826222
# ping
# 2022-11-18 10:44:07.828677
# ping
# 2022-11-18 10:44:22.832200
#            DEBUG    Found Jina AI Cloud authentication token                                             __main__.py:125
#            DEBUG    Running in online mode                                                               __main__.py:126
#            INFO     Reading config ...                                                                   __main__.py:133
#            DEBUG    Reading config from stream                                                           __main__.py:145
#            INFO     Parsing config ...                                                                   __main__.py:148
#            INFO     Config loaded 📜                                                                     __main__.py:150
#            INFO     Run name: stupefied-einstein                                                         __main__.py:152
#            INFO     Experiment name: finetuner                                                           __main__.py:153
#            DEBUG    Device set to [cpu]                                                                  __main__.py:156
#            DEBUG    Artifact ID set to 63775941344182ab9a8f7a58                                          __main__.py:164
#            INFO     Bulding the tuner components ...                                                     __main__.py:166
#            INFO     Building models ...                                                                    parser.py:193
#            DEBUG    Model name: xlm-roberta-base-ViT-B-32::laion5b_s13b_b90k                               parser.py:195
#            DEBUG    Model options: {}                                                                      parser.py:196
#            INFO     Loaded xlm-roberta-base-ViT-B-32 model config.                                        factory.py:127
#
# Downloading:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 615/615 [00:00<00:00, 991kB/s]
#
# Downloading:   0%|          | 0.00/1.04G [00:00<?, ?B/s]
# Downloading:   1%|          | 9.67M/1.04G [00:00<00:10, 101MB/s]
# Downloading:   2%|▏         | 19.7M/1.04G [00:00<00:10, 104MB/s]
# Downloading:   3%|▎         | 29.9M/1.04G [00:00<00:10, 105MB/s]
# Downloading:   4%|▍         | 40.0M/1.04G [00:00<00:10, 106MB/s]
# Downloading:   5%|▍         | 50.2M/1.04G [00:00<00:10, 106MB/s]
# Downloading:   6%|▌         | 60.4M/1.04G [00:00<00:09, 106MB/s]
# Downloading:   7%|▋         | 70.6M/1.04G [00:00<00:09, 106MB/s]
# Downloading:   8%|▊         | 80.8M/1.04G [00:00<00:09, 107MB/s]
# Downloading:   9%|▊         | 91.1M/1.04G [00:00<00:09, 107MB/s]
# Downloading:  10%|▉         | 101M/1.04G [00:01<00:09, 107MB/s]
# Downloading:  10%|█         | 112M/1.04G [00:01<00:09, 107MB/s]
# Downloading:  11%|█▏        | 122M/1.04G [00:01<00:13, 70.8MB/s]
# Downloading:  12%|█▏        | 130M/1.04G [00:01<00:14, 65.3MB/s]
# Downloading:  13%|█▎        | 140M/1.04G [00:01<00:13, 74.1MB/s]
# Downloading:  14%|█▍        | 150M/1.04G [00:01<00:11, 81.9MB/s]
# Downloading:  86%|████████▌ | 913M/1.04G [00:10<00:01, 88.3MB/s]
# Downloading:  87%|████████▋ | 923M/1.04G [00:10<00:01, 93.3MB/s]
# Downloading:  88%|████████▊ | 933M/1.04G [00:10<00:01, 97.1MB/s]
# Downloading:  89%|████████▊ | 944M/1.04G [00:10<00:01, 100MB/s]
# Downloading:  90%|████████▉ | 954M/1.04G [00:11<00:01, 102MB/s]
# Downloading:  91%|█████████ | 964M/1.04G [00:11<00:01, 104MB/s]
# Downloading:  92%|█████████▏| 975M/1.04G [00:11<00:00, 105MB/s]
# Downloading:  93%|█████████▎| 985M/1.04G [00:11<00:00, 106MB/s]
# Downloading:  94%|█████████▎| 995M/1.04G [00:11<00:00, 86.1MB/s]
# Downloading:  95%|█████████▍| 0.98G/1.04G [00:11<00:00, 91.5MB/s]
# Downloading:  95%|█████████▌| 0.99G/1.04G [00:11<00:00, 86.1MB/s]
# Downloading:  96%|█████████▋| 1.00G/1.04G [00:11<00:00, 91.6MB/s]
# Downloading:  97%|█████████▋| 1.01G/1.04G [00:11<00:00, 96.0MB/s]
# Downloading:  98%|█████████▊| 1.02G/1.04G [00:12<00:00, 99.3MB/s]
# Downloading:  99%|█████████▉| 1.03G/1.04G [00:12<00:00, 102MB/s]
# Downloading: 100%|██████████| 1.04G/1.04G [00:12<00:00, 90.9MB/s]
#
# Downloading:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Downloading:   0%|          | 51.2k/1.46G [00:00<1:25:35, 285kB/s]
# Downloading:   0%|          | 278k/1.46G [00:00<28:18, 862kB/s]
# Downloading:   0%|          | 1.18M/1.46G [00:00<07:46, 3.14MB/s]
# Downloading:   0%|          | 2.43M/1.46G [00:00<04:26, 5.49MB/s]
# Downloading:   0%|          | 4.97M/1.46G [00:00<02:13, 10.9MB/s]
# Downloading:   1%|          | 8.96M/1.46G [00:00<01:15, 19.2MB/s]
# Downloading:   1%|          | 13.4M/1.46G [00:00<00:54, 26.6MB/s]
# Downloading:   1%|          | 17.9M/1.46G [00:01<00:45, 31.9MB/s]
# Downloading:   2%|▏         | 22.5M/1.46G [00:01<00:40, 36.0MB/s]
# Downloading:   2%|▏         | 27.4M/1.46G [00:01<00:36, 39.8MB/s]
# Downloading:   2%|▏         | 31.6M/1.46G [00:01<00:35, 40.4MB/s]
# Downloading:   2%|▏         | 36.3M/1.46G [00:01<00:33, 42.3MB/s]
# Downloading:   3%|▎         | 40.6M/1.46G [00:01<00:38, 36.9MB/s]
# Downloading:   3%|▎         | 44.8M/1.46G [00:01<00:37, 38.2MB/s]
# Downloading:   3%|▎         | 49.4M/1.46G [00:01<00:34, 40.6MB/s]
# Downloading:   4%|▎         | 54.1M/1.46G [00:01<00:33, 42.2MB/s]
# Downloading:   4%|▍         | 58.8M/1.46G [00:01<00:32, 43.7MB/s]
# Downloading:   4%|▍         | 63.5M/1.46G [00:02<00:31, 44.8MB/s]
# Downloading:   5%|▍         | 68.2M/1.46G [00:02<00:30, 45.4MB/s]
# Downloading:  80%|███████▉  | 1.17G/1.46G [00:30<00:07, 38.6MB/s]
# Downloading:  80%|████████  | 1.17G/1.46G [00:30<00:08, 35.6MB/s]
# Downloading:  80%|████████  | 1.18G/1.46G [00:30<00:08, 34.5MB/s]
# Downloading:  81%|████████  | 1.18G/1.46G [00:30<00:08, 35.0MB/s]
# Downloading:  81%|████████  | 1.19G/1.46G [00:30<00:07, 37.0MB/s]
# Downloading:  81%|████████  | 1.19G/1.46G [00:30<00:07, 36.8MB/s]
# Downloading:  81%|████████▏ | 1.19G/1.46G [00:30<00:07, 36.7MB/s]
# Downloading:  82%|████████▏ | 1.20G/1.46G [00:30<00:06, 38.4MB/s]
# Downloading:  82%|████████▏ | 1.20G/1.46G [00:31<00:07, 35.2MB/s]
# Downloading:  82%|████████▏ | 1.20G/1.46G [00:31<00:07, 35.1MB/s]
# Downloading:  83%|████████▎ | 1.21G/1.46G [00:31<00:07, 35.1MB/s]
# Downloading:  83%|████████▎ | 1.21G/1.46G [00:31<00:06, 36.8MB/s]
# Downloading:  83%|████████▎ | 1.22G/1.46G [00:31<00:06, 36.7MB/s]
# Downloading:  83%|████████▎ | 1.22G/1.46G [00:31<00:06, 38.2MB/s]
# Downloading:  84%|████████▎ | 1.22G/1.46G [00:31<00:06, 35.5MB/s]
# Downloading:  84%|████████▍ | 1.23G/1.46G [00:31<00:06, 34.9MB/s]
# Downloading:  84%|████████▍ | 1.23G/1.46G [00:31<00:06, 35.0MB/s]
# Downloading:  84%|████████▍ | 1.24G/1.46G [00:32<00:06, 35.0MB/s]
# Downloading:  85%|████████▍ | 1.24G/1.46G [00:32<00:06, 36.2MB/s]
# Downloading:  85%|████████▍ | 1.24G/1.46G [00:32<00:06, 36.4MB/s]
# Downloading:  85%|████████▌ | 1.25G/1.46G [00:32<00:06, 35.7MB/s]
# Downloading:  85%|████████▌ | 1.25G/1.46G [00:32<00:05, 35.6MB/s]
# Downloading:  86%|████████▌ | 1.25G/1.46G [00:32<00:06, 34.7MB/s]
# Downloading:  86%|████████▌ | 1.26G/1.46G [00:32<00:05, 36.1MB/s]
# Downloading:  86%|████████▌ | 1.26G/1.46G [00:32<00:05, 37.6MB/s]
# Downloading:  86%|████████▋ | 1.27G/1.46G [00:32<00:05, 35.6MB/s]
# Downloading:  87%|████████▋ | 1.27G/1.46G [00:32<00:05, 35.9MB/s]
# Downloading:  87%|████████▋ | 1.27G/1.46G [00:33<00:05, 35.4MB/s]
# Downloading:  87%|████████▋ | 1.28G/1.46G [00:33<00:05, 36.5MB/s]
# Downloading:  88%|████████▊ | 1.28G/1.46G [00:33<00:04, 38.1MB/s]
# Downloading:  88%|████████▊ | 1.29G/1.46G [00:33<00:04, 38.4MB/s]
# Downloading:  88%|████████▊ | 1.29G/1.46G [00:33<00:04, 36.8MB/s]
# Downloading:  88%|████████▊ | 1.29G/1.46G [00:33<00:04, 38.4MB/s]
# Downloading:  89%|████████▊ | 1.30G/1.46G [00:33<00:04, 36.4MB/s]
# Downloading:  89%|████████▉ | 1.30G/1.46G [00:33<00:04, 35.6MB/s]
# Downloading:  89%|████████▉ | 1.31G/1.46G [00:33<00:04, 35.5MB/s]
# Downloading:  89%|████████▉ | 1.31G/1.46G [00:34<00:04, 35.9MB/s]
# Downloading:  90%|████████▉ | 1.31G/1.46G [00:34<00:04, 37.5MB/s]
# Downloading:  90%|████████▉ | 1.32G/1.46G [00:34<00:03, 37.9MB/s]
# Downloading:  90%|█████████ | 1.32G/1.46G [00:34<00:03, 37.3MB/s]
# Downloading:  90%|█████████ | 1.32G/1.46G [00:34<00:03, 37.0MB/s]
# Downloading:  91%|█████████ | 1.33G/1.46G [00:34<00:03, 36.4MB/s]
# Downloading:  91%|█████████ | 1.33G/1.46G [00:34<00:03, 37.9MB/s]
# Downloading:  91%|█████████▏| 1.34G/1.46G [00:34<00:03, 37.6MB/s]
# Downloading:  92%|█████████▏| 1.34G/1.46G [00:34<00:03, 36.0MB/s]
# Downloading:  92%|█████████▏| 1.34G/1.46G [00:34<00:03, 37.3MB/s]
# Downloading:  92%|█████████▏| 1.35G/1.46G [00:35<00:03, 37.9MB/s]
# Downloading:  92%|█████████▏| 1.35G/1.46G [00:35<00:03, 35.9MB/s]
# Downloading:  93%|█████████▎| 1.36G/1.46G [00:35<00:03, 35.7MB/s]
# Downloading:  93%|█████████▎| 1.36G/1.46G [00:35<00:03, 34.6MB/s]
# Downloading:  93%|█████████▎| 1.36G/1.46G [00:35<00:02, 36.7MB/s]
# Downloading:  93%|█████████▎| 1.37G/1.46G [00:35<00:02, 38.7MB/s]
# Downloading:  94%|█████████▎| 1.37G/1.46G [00:35<00:02, 35.9MB/s]
# Downloading:  94%|█████████▍| 1.38G/1.46G [00:35<00:02, 36.0MB/s]
# Downloading:  94%|█████████▍| 1.38G/1.46G [00:35<00:02, 34.5MB/s]
# Downloading:  94%|█████████▍| 1.38G/1.46G [00:36<00:02, 36.4MB/s]
# Downloading:  95%|█████████▍| 1.39G/1.46G [00:36<00:02, 37.0MB/s]
# Downloading:  95%|█████████▌| 1.39G/1.46G [00:36<00:01, 39.3MB/s]
# Downloading:  95%|█████████▌| 1.40G/1.46G [00:36<00:01, 37.4MB/s]
# Downloading:  96%|█████████▌| 1.40G/1.46G [00:36<00:01, 37.2MB/s]
# Downloading:  96%|█████████▌| 1.40G/1.46G [00:36<00:01, 37.6MB/s]
# Downloading:  96%|█████████▌| 1.41G/1.46G [00:36<00:01, 37.6MB/s]
# Downloading:  96%|█████████▋| 1.41G/1.46G [00:36<00:01, 35.3MB/s]
# Downloading:  97%|█████████▋| 1.42G/1.46G [00:36<00:01, 36.9MB/s]
# Downloading:  97%|█████████▋| 1.42G/1.46G [00:37<00:01, 38.3MB/s]
# Downloading:  97%|█████████▋| 1.42G/1.46G [00:37<00:01, 38.0MB/s]
# Downloading:  97%|█████████▋| 1.43G/1.46G [00:37<00:00, 38.0MB/s]
# Downloading:  98%|█████████▊| 1.43G/1.46G [00:37<00:00, 37.8MB/s]
# Downloading:  98%|█████████▊| 1.43G/1.46G [00:37<00:00, 38.9MB/s]
# Downloading:  98%|█████████▊| 1.44G/1.46G [00:37<00:00, 36.7MB/s]
# Downloading:  98%|█████████▊| 1.44G/1.46G [00:37<00:00, 35.8MB/s]
# Downloading:  99%|█████████▊| 1.45G/1.46G [00:37<00:00, 35.7MB/s]
# Downloading:  99%|█████████▉| 1.45G/1.46G [00:37<00:00, 37.7MB/s]
# Downloading:  99%|█████████▉| 1.45G/1.46G [00:37<00:00, 38.3MB/s]
# Downloading: 100%|█████████▉| 1.46G/1.46G [00:38<00:00, 38.3MB/s]
# Downloading: 100%|█████████▉| 1.46G/1.46G [00:38<00:00, 34.3MB/s]
# Downloading: 100%|██████████| 1.46G/1.46G [00:38<00:00, 38.3MB/s]
# [10:11:02] INFO     Loading pretrained xlm-roberta-base-ViT-B-32 weights (laion5b_s13b_b90k).             factory.py:161
#            INFO     Loaded xlm-roberta-base-ViT-B-32 model config.                                        factory.py:127
# [10:11:07] INFO     Loading pretrained xlm-roberta-base-ViT-B-32 weights (laion5b_s13b_b90k).             factory.py:161
#
# Downloading:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading:   1%|          | 36.0k/4.83M [00:00<00:24, 204kB/s]
# Downloading:   4%|▎         | 180k/4.83M [00:00<00:07, 665kB/s]
# Downloading:   8%|▊         | 420k/4.83M [00:00<00:03, 1.17MB/s]
# Downloading:  23%|██▎       | 1.13M/4.83M [00:00<00:01, 3.16MB/s]
# Downloading:  61%|██████    | 2.95M/4.83M [00:00<00:00, 8.08MB/s]
# Downloading: 100%|██████████| 4.83M/4.83M [00:00<00:00, 6.88MB/s]
#
# Downloading:   0%|          | 0.00/8.68M [00:00<?, ?B/s]
# Downloading:   1%|          | 84.0k/8.68M [00:00<00:18, 481kB/s]
# Downloading:   5%|▍         | 436k/8.68M [00:00<00:06, 1.38MB/s]
# Downloading:  20%|██        | 1.74M/8.68M [00:00<00:01, 4.25MB/s]
# Downloading:  49%|████▉     | 4.27M/8.68M [00:00<00:00, 10.2MB/s]
# Downloading:  83%|████████▎ | 7.19M/8.68M [00:00<00:00, 13.3MB/s]
# Downloading: 100%|██████████| 8.68M/8.68M [00:00<00:00, 11.1MB/s]
# [10:11:14] INFO     Loaded xlm-roberta-base-ViT-B-32 model config.                                        factory.py:127
# [10:11:19] INFO     Loading pretrained xlm-roberta-base-ViT-B-32 weights (laion5b_s13b_b90k).             factory.py:161
# [10:11:20] INFO     Building loss ...                                                                      parser.py:248
#            DEBUG    Loss name: CLIPLoss                                                                    parser.py:249
#            INFO     Building optimizer ...                                                                 parser.py:294
#            DEBUG    Optimizer name: Adam                                                                   parser.py:295
#            DEBUG    Optimizer options: {'lr': 1e-06}                                                       parser.py:296
#            INFO     Loading the training data ...                                                          parser.py:112
#            INFO     Pulling data from cloud storage ...                                                     parser.py:90
# 🔐 You are logged in to Jina AI as louis.milliken. To log out, use jina auth logout.
#   Deserializing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233/233 • 155 QPS • 0:00:00 • 24.4 MB
# [10:11:24] DEBUG    # training samples: 233                                                                parser.py:119
#            INFO     Loading the evaluation data ...                                                        parser.py:146
#            INFO     Pulling data from cloud storage ...                                                     parser.py:90
# ping
# 2022-11-18 10:44:37.839382
# ping
# 2022-11-18 10:44:52.841666
# ping
# 2022-11-18 10:45:07.844615
# ping
# 2022-11-18 10:45:22.847918
#   Deserializing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233/233 • 144 QPS • 0:00:00 • 25.2 MB
# [10:11:29] DEBUG    # eval samples: 233                                                                    parser.py:153
#            INFO     Model, data, callbacks, loss, miner and optimizer built successfully 🔥              __main__.py:169
#            INFO     Finetuning ...                                                                       __main__.py:174
# ping
# 2022-11-18 10:45:37.850659

# %% [markdown]
# Since some runs might take up to several hours/days, it's important to know how to reconnect to Finetuner and retrieve your run.
#
# ```python
# import finetuner
#
# finetuner.login()
# run = finetuner.get_run(run.name)
# ```
#
# You can continue monitoring the run by checking the status - `finetuner.run.Run.status()` or the logs - `finetuner.run.Run.logs()`.

# %% [markdown]
# ## Evaluating
# Currently, we don't have a user-friendly way to get evaluation metrics from the {class}`~finetuner.callback.EvaluationCallback` we initialized previously.
#
# ```bash
#            INFO     Done ✨                                                                              __main__.py:219
#            INFO     Saving fine-tuned models ...                                                         __main__.py:222
#            INFO     Saving model 'model' in /usr/src/app/tuned-models/model ...                          __main__.py:233
#            INFO     Pushing saved model to Jina AI Cloud ...                                                    __main__.py:240
# [10:38:14] INFO     Pushed model artifact ID: '62a1af491597c219f6a330fe'                                 __main__.py:246
#            INFO     Finished 🚀                                                                          __main__.py:248
# ```
#
# ```{admonition} Evaluation of CLIP
#
# In this example, we did not plug-in an `EvaluationCallback` since the callback can evaluate one model at one time.
# In most cases, we want to evaluate two models: i.e. use `CLIPTextEncoder` to encode textual Documents as `query_data` while use `CLIPImageEncoder` to encode image Documents as `index_data`.
# Then use the textual Documents to search image Documents.
#
# We have done the evaulation for you in the table below.
# ```
#
# TODO

# %% [markdown]
# ## Saving
#
# After the run has finished successfully, you can download the tuned model on your local machine:

# %%
artifact = run.save_artifact('m-clip-model')

# %% [markdown]
# ## Inference
#
# Now you saved the `artifact` into your host machine,
# let's use the fine-tuned model to encode a new `Document`:

# %%
text_da = DocumentArray([Document(text='setwas Text zum Codieren')])
image_da = DocumentArray([Document(uri='https://upload.wikimedia.org/wikipedia/commons/4/4e/Single_apple.png')])

clip_text_encoder = finetuner.get_model(artifact=artifact, select_model='clip-text')
clip_image_encoder = finetuner.get_model(artifact=artifact, select_model='clip-vision')

finetuner.encode(model=clip_text_encoder, data=text_da)
finetuner.encode(model=clip_image_encoder, data=image_da)

print(text_da.embeddings.shape)
print(image_da.embeddings.shape)

# %% [markdown]
# ```bash
# (1, 512)
# (1, 512)
# ```
#
# ```{admonition} what is select_model?
# When fine-tuning CLIP, we are fine-tuning the CLIPVisionEncoder and CLIPTextEncoder in parallel.
# The artifact contains two models: `clip-vision` and `clip-text`.
# The parameter `select_model` tells finetuner which model to use for inference, in the above example,
# we use `clip-text` to encode a Document with text content.
# ```
#
# ```{admonition} Inference with ONNX
# In case you set `to_onnx=True` when calling `finetuner.fit` function,
# please use `model = finetuner.get_model(artifact, is_onnx=True)`
# ```
